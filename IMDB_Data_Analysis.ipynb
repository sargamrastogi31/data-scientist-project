# %% [markdown]
# Name: Sargam Rastogi
# Batch: DST20124

# %%
# Import Pandas and NumPy

import numpy as np
import pandas as pd

#pip install db-sqlite3
#SQLite in general is a server-less database that you can use within almost all programming languages including Python.
import sqlite3

# %% [markdown]
# We import the sqlite3 module and then create a connection object which will connect us to the database and will let us execute the SQL statements.
#
# sqlite3.connect(Database)
#
# __cursor()__ - we can use the cursor object to call the execute() method to execute any SQL queries.
#
# __STEPS:__
# To query data in an SQLite database from Python, you use these steps:
#
# - First, establish a connection to the SQLite database by creating a Connection object.
# - Next, create a Cursor object using the cursor method of the Connection object.
# - Then, execute a SELECT statement.
# - After that, call the fetchall() method of the cursor object to fetch the data.
# - Finally, loop the cursor and process each row individually.

# %%
db = 'movies.sqlite'


conn = sqlite3.connect(db)
cur = conn.cursor()

# %% [markdown]
# ## QUESTIONS
# ### Question 1: Can you get all data about movies?

# %%
cur.execute('SELECT * FROM movies')
#use the cursor object to call the execute() method to execute any SQL queries.
movies = cur.fetchall()

#movies -> if u print movies , all the data shown in list manner, can't understanadble

#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.

movies = pd.DataFrame(movies, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.

print('Shape of Movies data :',movies.shape)
print('\n\n\n')
movies.head(10)
#Displays first 3 rows in the table
# Out:
# Shape of Movies data : (4773, 13)
#       id                            original_title     budget  popularity  \
# 0  43597                                    Avatar  237000000         150
# 1  43598  Pirates of the Caribbean: At World's End  300000000         139
# 2  43599                                   Spectre  245000000         107
# 3  43600                     The Dark Knight Rises  250000000         112
# 4  43601                               John Carter  260000000          43
# 5  43602                              Spider-Man 3  258000000         115
# 6  43603                                   Tangled  260000000          48
# 7  43604                   Avengers: Age of Ultron  280000000         134
# 8  43605    Harry Potter and the Half-Blood Prince  250000000          98
# 9  43606        Batman v Superman: Dawn of Justice  250000000         155
#
#   release_date     revenue                                     title  \
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4773 entries, 0 to 4772
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              4773 non-null   int64
#  1   original_title  4773 non-null   object
#  2   budget          4773 non-null   int64
#  3   popularity      4773 non-null   int64
#  4   release_date    4773 non-null   object
#  5   revenue         4773 non-null   int64
#  6   title           4773 non-null   object
#  7   vote_average    4773 non-null   float64
#  8   vote_count      4773 non-null   int64
#  9   overview        4770 non-null   object
#  10  tagline         3951 non-null   object
#  11  uid             4773 non-null   int64
#  12  director_id     4773 non-null   int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 484.9+ KB

# %% [markdown]
# ## Question 2: How do you get all data about directors?

# %%
cur.execute('SELECT * FROM directors')
#use the cursor object to call the execute() method to execute any SQL queries.

directors = cur.fetchall()
#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.


directors = pd.DataFrame(directors, columns = ['name', 'id', 'gender', 'uid', 'department'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.

print('Shape of Directors data :',directors.shape)
print('\n\n\n')


directors.head(11)
# Out:
# Shape of Directors data : (2349, 5)
#                  name    id  gender    uid department
# 0       James Cameron  4762       2   2710  Directing
# 1      Gore Verbinski  4763       2   1704  Directing
# 2          Sam Mendes  4764       2     39  Directing
# 3   Christopher Nolan  4765       2    525  Directing
# 4      Andrew Stanton  4766       2      7  Directing
# 5           Sam Raimi  4767       2   7623  Directing
# 6        Byron Howard  4768       2  76595  Directing
# 7         Joss Whedon  4769       2  12891  Directing
# 8         David Yates  4770       2  11343  Directing
# 9         Zack Snyder  4771       2  15217  Directing
# 10       Bryan Singer  4772       2   9032  Directing

# %%
directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2349 entries, 0 to 2348
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        2349 non-null   object
#  1   id          2349 non-null   int64
#  2   gender      2349 non-null   int64
#  3   uid         2349 non-null   int64
#  4   department  2349 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 91.9+ KB

# %% [markdown]
# ## Question 3: Check how many movies are present in iMDB.

# %%
cur.execute('SELECT count(title) from movies')
count = cur.fetchall()
print(f" the number of movies present in the imdb table is {count[0]}")
# Out:
#  the number of movies present in the imdb table is (4773,)

# %% [markdown]
# QUESTION 4 find these 3 directors: james cameron ; Luc besson ; john woo

# %%
cur.execute("select * from directors where name in ('James Cameron', 'Luc Besson','John Woo')")
three_directors = cur.fetchall()
three_directors
# Out:
# [('James Cameron', 4762, 2, 2710, 'Directing'),
#  ('John Woo', 4893, 2, 11401, 'Directing'),
#  ('Luc Besson', 4949, 2, 59, 'Directing')]

# %% [markdown]
# Question 5 find all directors with name starting with steven

# %%
cur.execute("select * from directors where name like 'Steven%'")
steven_directors = cur.fetchall()
steven_directors
# Out:
# [('Steven Spielberg', 4799, 2, 488, 'Directing'),
#  ('Steven Soderbergh', 4909, 2, 1884, 'Directing'),
#  ('Steven Brill', 5013, 2, 32593, 'Directing'),
#  ('Steven Zaillian', 5117, 2, 2260, 'Directing'),
#  ('Steven Quale', 5216, 2, 93214, 'Directing'),
#  ('Steven Seagal', 5221, 2, 23880, 'Directing'),
#  ('Steven E. de Souza', 5390, 2, 1726, 'Directing'),
#  ('Steven Shainberg', 5803, 2, 67795, 'Directing'),
#  ('Steven R. Monroe', 6713, 2, 88039, 'Directing')]

# %% [markdown]
# Question 6 count female directors

# %%
cur.execute("select count(*) from directors where gender == 1")
female_directors = cur.fetchall()
female_directors[0]
print("the number of female directors are",female_directors[0][0]) #using twice will change tuple answer
# Out:
# the number of female directors are 150

# %% [markdown]
# Question 7 find the name of the 10th first women directors

# %%
cur.execute("select name from directors where gender == 1")
tenth_director = cur.fetchall()
print(f"the tenth first women is {tenth_director[9][0]} ")
# Out:
# the tenth first women is Angelina Jolie

# %% [markdown]
# Question 8 what are the 3 most popular movies

# %%
cur.execute("SELECT title FROM movies ORDER BY popularity DESC LIMIT 3")
most_popular = cur.fetchall()
print(f"the 3 most popular movies are {most_popular[0][0]},{most_popular[1][0]},{most_popular[2][0]}")
# Out:
# the 3 most popular movies are Minions,Interstellar,Deadpool

# %% [markdown]
# question 9 what are the 3 most bankable movies

# %%
cur.execute("SELECT title FROM movies ORDER BY budget DESC LIMIT 3")
most_bankable = cur.fetchall()
print(f"the 3 most bankable movies are {most_bankable[0][0]},{most_bankable[1][0]},{most_bankable[2][0]}")
# Out:
# the 3 most bankable movies are Pirates of the Caribbean: On Stranger Tides,Pirates of the Caribbean: At World's End,Avengers: Age of Ultron

# %% [markdown]
# Question 10 what is the most awared average vote since the january 1st,2000

# %%
cur.execute("SELECT title FROM movies where release_date>'2000-01-01' order by vote_average desc limit 1")
most_awared = cur.fetchall()
print(f"the most awared average vote {most_awared[0][0]}")
# Out:
# the most awared average vote Sardaarji

# %% [markdown]
# Question 11 which movies were directed by Brenda chapman

# %%
cur.execute("select title from movies join directors on directors.id = movies.director_id where directors.name = 'Brenda Chapman'")
directs_by = cur.fetchall()
print(f"the movies directes by Brenda chapman {directs_by[0][0]}")
# Out:
# the movies directes by Brenda chapman Brave

# %% [markdown]
# Question 12 whose director made the most movies ?

# %%
cur.execute('select name from directors join movies on directors.id = movies.director_id group by director_id order by count(name) desc limit 1')
director_movie = cur.fetchall()
print(f"the director who made the most movie is {director_movie[0][0]}")
# Out:
# the director who made the most movie is Steven Spielberg

# %% [markdown]
# Question 13 whose director is the most bankable

# %%
cur.execute("select name from directors join movies on directors.id = movies.director_id group by director_id order by sum(budget) desc limit 1")
director_bankable = cur.fetchall()
print(f"the most banakable director {director_bankable[0][0]}")
# Out:
# the most banakable director Steven Spielberg

# %% [markdown]
# ## List out Top 10 highest budget made movies

# %%
cur.execute('SELECT * FROM directors')
#use the cursor object to call the execute() method to execute any SQL queries.

directors = cur.fetchall()
#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.


directors = pd.DataFrame(directors, columns = ['name', 'id', 'gender', 'uid', 'department'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.

print('Shape of Directors data :',directors.shape)
print('\n\n\n')


directors.head(10)
# Out:
# Shape of Directors data : (2349, 5)
#                 name    id  gender    uid department
# 0      James Cameron  4762       2   2710  Directing
# 1     Gore Verbinski  4763       2   1704  Directing
# 2         Sam Mendes  4764       2     39  Directing
# 3  Christopher Nolan  4765       2    525  Directing
# 4     Andrew Stanton  4766       2      7  Directing
# 5          Sam Raimi  4767       2   7623  Directing
# 6       Byron Howard  4768       2  76595  Directing
# 7        Joss Whedon  4769       2  12891  Directing
# 8        David Yates  4770       2  11343  Directing
# 9        Zack Snyder  4771       2  15217  Directing

# %% [markdown]
# # List out top 10 highest budget movies

# %%
cur.execute("select * from movies order by budget desc limit 10")
high_budget = cur.fetchall()
top_budget= pd.DataFrame(high_budget, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
top_budget
# Out:
#       id                               original_title     budget  popularity  \
# 0  43614  Pirates of the Caribbean: On Stranger Tides  380000000         135
# 1  43598     Pirates of the Caribbean: At World's End  300000000         139
# 2  43604                      Avengers: Age of Ultron  280000000         134
# 3  43607                             Superman Returns  270000000          57
# 4  43601                                  John Carter  260000000          43
# 5  43603                                      Tangled  260000000          48
# 6  43602                                 Spider-Man 3  258000000         115
# 7  43610                              The Lone Ranger  255000000          49
# 8  43600                        The Dark Knight Rises  250000000         112
# 9  43605       Harry Potter and the Half-Blood Prince  250000000          98
#
#   release_date     revenue                                        title  \
# ...

# %% [markdown]
# these are the top 10 movies having budget

# %% [markdown]
# List out 10 popularity on movies

# %%
cur.execute("select * from movies order by popularity desc limit 10")
high_popularity = cur.fetchall()
top_pop= pd.DataFrame(high_popularity, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
top_pop
# Out:
#       id                                     original_title     budget  \
# 0  44143                                            Minions   74000000
# 1  43692                                       Interstellar  165000000
# 2  44385                                           Deadpool   58000000
# 3  43691                            Guardians of the Galaxy  170000000
# 4  43724                                 Mad Max: Fury Road  150000000
# 5  43625                                     Jurassic World  150000000
# 6  43796  Pirates of the Caribbean: The Curse of the Bla...  140000000
# 7  43679                     Dawn of the Planet of the Apes  170000000
# 8  43797              The Hunger Games: Mockingjay - Part 1  125000000
# 9  43685                                         Big Hero 6  165000000
#
#    popularity release_date     revenue  \
# 0         875   2015-06-17  1156730962
# 1         724   2014-11-05   675120017
# 2         514   2016-02-09   783112979
# ...

# %% [markdown]
# what are the top 10 revenue movies

# %%
cur.execute("select * from movies order by revenue desc limit 10")
high_revenue = cur.fetchall()
top_rev = pd.DataFrame(high_revenue, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
top_rev
# Out:
#       id              original_title     budget  popularity release_date  \
# 0  43597                      Avatar  237000000         150   2009-12-10
# 1  43622                     Titanic  200000000         100   1997-11-18
# 2  43613                The Avengers  220000000         144   2012-04-25
# 3  43625              Jurassic World  150000000         418   2015-06-09
# 4  43641                   Furious 7  190000000         102   2015-04-01
# 5  43604     Avengers: Age of Ultron  280000000         134   2015-04-22
# 6  43721                      Frozen  150000000         165   2013-11-27
# 7  43628                  Iron Man 3  200000000          77   2013-04-18
# 8  44143                     Minions   74000000         875   2015-06-17
# 9  43623  Captain America: Civil War  250000000         198   2016-04-27
#
#       revenue                       title  vote_average  vote_count  \
# 0  2787965087                      Avatar           7.2       11800
# ...

# %% [markdown]
# display most popular movies with vote_average

# %%
cur.execute("select * from movies order by vote_average desc limit 10")
vote_avg = cur.fetchall()
avg = pd.DataFrame(vote_avg, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
avg
# Out:
#       id            original_title    budget  popularity release_date  \
# 0  47116          Stiff Upper Lips         0           0   1998-06-12
# 1  47642     Dancer, Texas Pop. 81         0           0   1998-05-01
# 2  47589                 Sardaarji         0           0   2015-06-26
# 3  45983            One Man's Hero         0           0   1999-08-02
# 4  45478  The Shawshank Redemption  25000000         136   1994-09-23
# 5  46567        There Goes My Baby  10500000           0   1994-09-02
# 6  46393     The Prisoner of Zenda         0           4   1937-09-03
# 7  46934             The Godfather   6000000         143   1972-03-14
# 8  44259                Fight Club  63000000         146   1999-10-15
# 9  45415          Schindler's List  22000000         104   1993-11-29
#
#      revenue                     title  vote_average  vote_count  \
# 0          0          Stiff Upper Lips          10.0           1
# ...

# %% [markdown]
# list out paticular movie for voting average and votecount

# %%
cur.execute("select * from movies order by vote_average desc limit 10")
vote_avg_count = cur.fetchall()
avg_count = pd.DataFrame(vote_avg_count, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
avg_count
# Out:
#       id            original_title    budget  popularity release_date  \
# 0  47116          Stiff Upper Lips         0           0   1998-06-12
# 1  47642     Dancer, Texas Pop. 81         0           0   1998-05-01
# 2  47589                 Sardaarji         0           0   2015-06-26
# 3  45983            One Man's Hero         0           0   1999-08-02
# 4  45478  The Shawshank Redemption  25000000         136   1994-09-23
# 5  46567        There Goes My Baby  10500000           0   1994-09-02
# 6  46393     The Prisoner of Zenda         0           4   1937-09-03
# 7  46934             The Godfather   6000000         143   1972-03-14
# 8  44259                Fight Club  63000000         146   1999-10-15
# 9  45415          Schindler's List  22000000         104   1993-11-29
#
#      revenue                     title  vote_average  vote_count  \
# 0          0          Stiff Upper Lips          10.0           1
# ...

# %% [markdown]
# list out the director names with number of movies and revenue

# %%
cur.execute("select name,count(*) as 'total movies',sum(revenue) as 'total revenue' from directors join movies where directors.id == movies.director_id group by director_id order by sum(revenue) desc")
direct = cur.fetchall()
dir = pd.DataFrame(direct, columns = ['Director_name', 'total movies', 'total revenue'])
dir.head(10)
# Out:
#        Director_name  total movies  total revenue
# 0   Steven Spielberg            27     9147393164
# 1      Peter Jackson             9     6498642820
# 2      James Cameron             7     5883569439
# 3        Michael Bay            12     5832524638
# 4  Christopher Nolan             8     4227483234
# 5     Chris Columbus            11     3725631503
# 6    Robert Zemeckis            13     3590622002
# 7       George Lucas             5     3339113893
# 8         Tim Burton            14     3337418241
# 9       Ridley Scott            16     3189557997
